# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib widget
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
sys.path.insert(0,'..')
from neurotrack.testing import postprocess, evaluation, pipeline

# %%
input_json = '../configs/test_example.json'
test_pipeline = pipeline.TestingPipeline(input_json)
# Out:
# ✓ Configuration validated successfully
#   Test name: test_1-20-26
#   Output directory: /home/brysongray/data/neurotrack_data/inference_outputs/pipeline_test/

# %%
# Test run inference
inference_results = test_pipeline._run_inference()
# Out:
#   Loading models...
#     Loading SAC actor from: /home/brysongray/data/neurotrack_data/model_weights/sac_weights/training_outputs_1-16/model_state_dicts_convex_composite_images_01-16-26.pt
#     ✓ SAC actor loaded
#   Creating dataset and environment...
#     ✓ Environment created with 25 images
#   Running inference on 25 images...
#     n_trials: 1
#     step_size: 2.0
#     step_width: 4.0
# Processing image 1/25
# Processing image 2/25
# Processing image 3/25
# Processing image 4/25
